# %%
import os
import numpy as np
from tqdm import tqdm 
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.integrate import quad
from scipy.signal import find_peaks
from scipy.optimize import curve_fit
from scipy.integrate import solve_ivp

mpl.rc('figure', figsize=(12, 6))
mpl.rc('text', usetex = False)
mpl.rc('font', family = 'serif')
mpl.rc('font', size = '14')
mpl.rc('xtick', labelsize=14) 
mpl.rc('ytick', labelsize=14)
mpl.rcParams['mathtext.fontset'] = 'stix'

# %%
"""Definimos las direcciones de los archivos"""

# Narrow Resonance
dirk005 = "./data/q5050/N256-kIR0.05-kcutoff100/"
dirk02 = "./data/q5050/N256-kIR0.2-kcutoff100/"
dirk08 = "./data/q5050/N256-kIR0.8-kcutoff100/"


""""Definimos los kIRs a graficar"""

k005 = 0.05
k02 = 0.2
k08 = 0.8

# %% [markdown]
# # Buscamos las bandas de resonancia

# %%
# Función para armarse la matriz de monodromía y calcular los coeficientes de Floquet
def mu_lphi4(k, q, y0, Tosc):
    phi0, phi_dot0 = y0

    def pert(t, y, k, q):
        phi, phi_dot, chi_k, chi_dot_k = y
        phi_ddot = - phi**3
        chi_ddot_k = - (k**2 + q * phi**2) * chi_k
        return [phi_dot, phi_ddot, chi_dot_k, chi_ddot_k]

    t_span = (0, Tosc)

    sol1 = solve_ivp(pert, t_span, [phi0, phi_dot0, 1.0, 0.0], t_eval=[Tosc], method='RK45', rtol=1e-4, args=(k, q))
    y_final1 = sol1.y[:, -1]

    sol2 = solve_ivp(pert, t_span, [phi0, phi_dot0, 0.0, 1.0], t_eval=[Tosc], method='RK45', rtol=1e-4, args=(k, q))
    y_final2 = sol2.y[:, -1]

    M = np.array([
        [y_final1[2], y_final2[2]],
        [y_final1[3], y_final2[3]]
    ])

    tr_M = np.trace(M)
    argument = np.abs(tr_M / 2.0)

    if argument > 1.0:
        mu = np.arccosh(argument) / Tosc
        return mu
    else:
        return 0.0
    
# Función para calcular el período de oscilación del inflatón
def oscilation(E):
    def integrand(phi):
        V = 0.25 * phi**4
        return 1.0 / np.sqrt(2 * (E - V))
    phimax = (4*E)**(1/4)
    integral, _ = quad(integrand, 0, phimax)
    Tosc = 4*integral
    return Tosc

# %%
"""Parámetros"""

phi0 = 1
phi_dot0 = phi0**2/np.sqrt(2)
q = 5050
y0 = (phi0, phi_dot0)
E = 0.5 * phi_dot0**2 + 0.25 * phi0**4
ks = np.logspace(-1, 1, 1000)
Tosc = oscilation(E)

# %%
mu = np.zeros(len(ks), dtype=complex)
muq3 = np.zeros(len(ks), dtype=complex)

for j, k in enumerate(tqdm(ks)):
    mu[j] = mu_lphi4(k, q, y0, Tosc)
    muq3[j] = mu_lphi4(k, 3, y0, Tosc) # Para ver el inflatón
# Out:
# 100%|██████████| 1000/1000 [02:15<00:00,  7.40it/s]

# %%
#Calculamos el máximo y el ancho de cada banda de inestabilidad
max_mu = np.max(np.real(mu))
k_max = ks[np.argmax(np.real(mu))]
k_delta = ks[np.where(np.real(mu) >= max_mu/2)[0]]

max_muq3 = np.max(np.real(muq3))
k_maxq3 = ks[np.argmax(np.real(muq3))]
k_deltaq3 = ks[np.where(np.real(muq3) >= max_muq3/2)[0]]

# %%
plt.figure(figsize=(12, 6))

plt.title(r'Coeficiente de Floquet para $q=0.5$')
plt.plot(ks, np.real(mu), lw = 5, color = "#88086c")
plt.xlabel(r'$k$')
plt.ylabel(r'$\mu_k$')
plt.xscale('log')
plt.grid(alpha = 0.3)
plt.axvspan(k_delta[-1], k_delta[0], color='green', alpha=0.3)
plt.axvline(x=k_max, color='red', linestyle='--', lw=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Scale factor $a(\tilde\eta)$
#
# The file contains the following columns:
#
# $\tilde\eta$ | $a$ | $a'$ | $\frac{a'}{a}$

# %%
expansion = False

if expansion == True:
    # load the file in aDat
    aDat = np.loadtxt(dir + "average_scale_factor.txt")
    
    #plot a
    plt.figure(0)
    plt.plot(aDat[:,0], aDat[:,1])
    plt.ylabel("$a$")
    plt.xlabel('$\\tilde\eta$')
    
    #plot a'
    plt.figure(1)
    plt.plot(aDat[:,0], aDat[:,2])
    plt.ylabel("$a'$")
    plt.xlabel('$\\tilde\eta$')
    
    
    #plot a'/a
    plt.figure(2)
    plt.plot(aDat[:,0], aDat[:,3])
    plt.ylabel("$a'/a$")
    plt.xlabel("$\\tilde\eta$");

else:
    aDat = None

# %% [markdown]
# # Volume average of fields

# %% [markdown]
# The files for the averages of the scalar fields contain the following columns:
#
# $\eta$ | $\langle \tilde\phi_n \rangle$ | $\langle \tilde\phi'_n \rangle$ | $\langle \tilde\phi^2_n \rangle$ | $\langle \tilde\phi^{'2}_n \rangle$ | $\mathrm{rms}(\tilde\phi_n) $ | $\mathrm{rms}(\tilde\phi'_n) $

# %%
# Define a function for the plots, as we are gonna do 
# the same for both fields
def plot_fld(fldDat, fldNum="", aDat=None):
    plt.plot(fldDat[:,0], fldDat[:,1])
    plt.xlabel("$\\tilde\eta$")
    plt.ylabel("$\langle\phi_"+ fldNum +"\\rangle$")
    
    if aDat is not None:
        plt.figure(1)
        plt.plot(fldDat[:,0], aDat[:,1] * fldDat[:,1])
        plt.xlabel("$\\tilde\eta$")
        plt.ylabel("$a\cdot\langle\phi_"+ fldNum +" \\rangle$")
    
        plt.figure(2)
        plt.plot(fldDat[:,0], aDat[:,1] * fldDat[:,5])
        plt.xlabel("$\\tilde\eta$")
        plt.ylabel("$a\cdot\mathrm{rms}(\phi_"+ fldNum +")$")
        plt.yscale('log')

# %% [markdown]
# ## Field $0$ (inflaton)

# %%
infDatk005 = np.loadtxt(dirk005 + "average_scalar_0.txt")
infDatk02 = np.loadtxt(dirk02 + "average_scalar_0.txt")
infDatk08 = np.loadtxt(dirk08 + "average_scalar_0.txt")

plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plot_fld(infDatk005,"0",aDat)
plt.title(r'Campo inflatón para $kIR = 0.05$')

plt.subplot(1, 3, 2)
plot_fld(infDatk02,"0",aDat)
plt.title(r'Campo inflatón para $kIR = 0.2$')

plt.subplot(1, 3, 3)
plot_fld(infDatk08,"0",aDat)
plt.title(r'Campo inflatón para $kIR = 0.8$')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Field $1$ (daughter field)

# %%
infDatk005 = np.loadtxt(dirk005 + "average_scalar_1.txt")
infDatk02 = np.loadtxt(dirk02 + "average_scalar_1.txt")
infDatk08 = np.loadtxt(dirk08 + "average_scalar_1.txt")

plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plot_fld(infDatk005,"1",aDat)
plt.title(r'Campo hijo para $kIR = 0.05$')

plt.subplot(1, 3, 2)
plot_fld(infDatk02,"1",aDat)
plt.title(r'Campo hijo para $kIR = 0.2$')

plt.subplot(1, 3, 3)
plot_fld(infDatk08,"1",aDat)
plt.title(r'Campo hijo para $kIR = 0.8$')

plt.tight_layout()
plt.show()

# %% [markdown]
# # "Energy conservation" (the $1^{st}$ Friedmann's equation is satisfied)

# %% [markdown]
# The file  that checks the first Friedmann's equation contains
#
# $\tilde\eta$ | $\frac{\langle LHS - RHS\rangle}{\langle LHS + RHS\rangle}$ | $\langle LHS \rangle$ | $\langle RHS \rangle$

# %%
enConsDatk005 = np.loadtxt(dirk005 + "average_energy_conservation.txt")
enConsDatk02 = np.loadtxt(dirk02 + "average_energy_conservation.txt")
enConsDatk08 = np.loadtxt(dirk08 + "average_energy_conservation.txt")


plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plt.plot(enConsDatk005[:,0], enConsDatk005[:,1])
plt.yscale('log')
plt.ylim([1e-8,0.01])
plt.title(r'$kIR = 0.05$')

plt.subplot(1, 3, 2)
plt.plot(enConsDatk02[:,0], enConsDatk02[:,1])
plt.yscale('log')
plt.ylim([1e-8,0.01])
plt.title(r'$kIR = 0.2$')

plt.subplot(1, 3, 3)
plt.plot(enConsDatk08[:,0], enConsDatk08[:,1])
plt.yscale('log')
plt.ylim([1e-8,0.01])
plt.title(r'$kIR = 0.8$')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Energy densities
#
# The file with the energy densities contains
#
# $\tilde\eta$ | $\tilde E_K^{(0)}$ | $\tilde E_G^{(0)}$ |$\dots$| $\tilde E_K^{(N_s-1)}$ | $\tilde E_G^{(N_s-1)}$ |  $\tilde E_V^{(0)}$ | $\dots$ |  $\tilde E_V^{(N_p-1)}$ | $\langle \tilde \rho \rangle$

# %%
enDatk005 = np.loadtxt(dirk005 + "average_energies.txt")
enDatk02 = np.loadtxt(dirk02 + "average_energies.txt")
enDatk08 = np.loadtxt(dirk08 + "average_energies.txt")

nColumnsk005 = np.shape(enDatk005)[1]
nColumnsk02 = np.shape(enDatk02)[1]
nColumnsk08 = np.shape(enDatk08)[1]

# set explicitly different colors, so we know who is who
colors = ["tab:blue", "tab:orange", "tab:green", "tab:red", "tab:purple", "tab:brown", "tab:pink"]

plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
for i in range(1,nColumnsk005):
    plt.plot(enDatk005[:,0], enDatk005[:,i], color = colors[i-1])
plt.title(r'$kIR = 0.05$')
plt.yscale('log')
plt.xlabel("$\\tilde \eta$")
plt.ylabel("$\langle \\rho's\\rangle$")

plt.subplot(1, 3, 2)
for i in range(1,nColumnsk02):
    plt.plot(enDatk02[:,0], enDatk02[:,i], color = colors[i-1])
plt.title(r'$kIR = 0.2$')
plt.yscale('log')
plt.xlabel("$\\tilde \eta$")
plt.ylabel("$\langle \\rho's\\rangle$")

plt.subplot(1, 3, 3)
for i in range(1,nColumnsk08):
    plt.plot(enDatk08[:,0], enDatk08[:,i], color = colors[i-1])
plt.title(r'$kIR = 0.8$')
plt.yscale('log')
plt.xlabel("$\\tilde \eta$")
plt.ylabel("$\langle \\rho's\\rangle$")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Spectra

# %% [markdown]
# Spectra output varies depending on the option. The default one generates a txt file with the following columns:
#
# $\tilde k$ | $\tilde\Delta_{\tilde\phi}$ | $\tilde\Delta_{\tilde\phi'}$ | $\tilde n_{\tilde\phi}$ | bin multiplicity

# %%
def load_spectrum(filename, comment = '#'):
    # The next few lines open the file and count
    # how many bins in one spectrum
    file = open(filename)
    nBins = 0
    # read first line
    line = file.readline()
    # while no blank we continue
    while line != "\n":
        # if not a comment line (header for instance)
        # we count one line
        if(line[0] != comment):
            nBins +=1
        # read next line
        line = file.readline()
    file.close()

    # now we know nBins. We still need to actually read the data.
    fileSp = np.loadtxt(filename, comments=comment)

    # find how many spectra are in the files
    nSpectra = len(fileSp) / nBins

    return fileSp, int(nBins), int(nSpectra)


def plot_spectrum(spectra, column, nBins, nSpectra, colormap='plasma'):
    colors = plt.get_cmap(colormap)
    norm = plt.Normalize(vmin=0, vmax=nSpectra-1)
    sm = plt.cm.ScalarMappable(cmap=colors, norm=norm)
    sm.set_array([])

    for i in range(nSpectra):
        plt.plot(
            spectra[i*nBins:(i+1)*nBins, 0],
            spectra[i*nBins:(i+1)*nBins, column],
            color=colors(i/nSpectra)
        )
    plt.xscale('log')
    plt.yscale('log')
    plt.grid(True, which="both", ls="--")
    plt.xlabel('$\\tilde k$', fontsize=20, labelpad=5)

    # Agrega la barra de colores asociada al eje actual
    cbar = plt.colorbar(sm, ax=plt.gca(), pad=0.02)
    cbar.set_label(r'$t$', fontsize=20, rotation=10)
    cbar.ax.tick_params(labelsize=16)

# %% [markdown]
# ## Inflaton

# %%
infSpk005, nBinsk005, nSpectrak005 = load_spectrum(dirk005 + "spectra_scalar_0.txt")
infSpk02, nBinsk02, nSpectrak02 = load_spectrum(dirk02 + "spectra_scalar_0.txt")
infSpk08, nBinsk08, nSpectrak08 = load_spectrum(dirk08 + "spectra_scalar_0.txt")

plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plot_spectrum(infSpk005, 2,  nBinsk005, nSpectrak005)
plt.ylabel('$\\tilde\Delta_{\\tilde\phi_0\'}$')
plt.title(r'Espectro del campo inflatón para $kIR = 0.05$')
plt.axvline(k_maxq3, color='k', linestyle='--')
plt.axvspan(k_deltaq3[-1], k_deltaq3[0], color='green', alpha=0.3)

plt.subplot(1, 3, 2)
plot_spectrum(infSpk02, 2,  nBinsk02, nSpectrak02)
plt.ylabel('$\\tilde\Delta_{\\tilde\phi_0\'}$')
plt.title(r'Espectro del campo inflatón para $kIR = 0.2$')
plt.axvline(k_maxq3, color='k', linestyle='--')
plt.axvspan(k_deltaq3[-1], k_deltaq3[0], color='green', alpha=0.3)

plt.subplot(1, 3, 3)
plot_spectrum(infSpk08, 2,  nBinsk08, nSpectrak08)
plt.ylabel('$\\tilde\Delta_{\\tilde\phi_0\'}$')
plt.title(r'Espectro del campo inflatón para $kIR = 0.8$')
plt.axvline(k_maxq3, color='k', linestyle='--')
plt.axvspan(k_deltaq3[-1], k_deltaq3[0], color='green', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Daughter field

# %%
infSpk005, nBinsk005, nSpectrak005 = load_spectrum(dirk005 + "spectra_scalar_1.txt")
infSpk02, nBinsk02, nSpectrak02 = load_spectrum(dirk02 + "spectra_scalar_1.txt")
infSpk08, nBinsk08, nSpectrak08 = load_spectrum(dirk08 + "spectra_scalar_1.txt")

plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plot_spectrum(infSpk005, 2,  nBinsk005, nSpectrak005)
plt.ylabel('$\\tilde\Delta_{\\tilde\phi_0\'}$')
plt.title(r'Espectro del campo hijo para $kIR = 0.05$')
plt.axvline(k_max, color='k', linestyle='--')
plt.axvspan(k_delta[-1], k_delta[0], color='green', alpha=0.3)

plt.subplot(1, 3, 2)
plot_spectrum(infSpk02, 2,  nBinsk02, nSpectrak02)
plt.ylabel('$\\tilde\Delta_{\\tilde\phi_0\'}$')
plt.title(r'Espectro del campo hijo para $kIR = 0.2$')
plt.axvline(k_max, color='k', linestyle='--')
plt.axvspan(k_delta[-1], k_delta[0], color='green', alpha=0.3)

plt.subplot(1, 3, 3)
plot_spectrum(infSpk08, 2,  nBinsk08, nSpectrak08)
plt.ylabel('$\\tilde\Delta_{\\tilde\phi_0\'}$')
plt.title(r'Espectro del campo hijo para $kIR = 0.8$')
plt.axvline(k_max, color='k', linestyle='--')
plt.axvspan(k_delta[-1], k_delta[0], color='green', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # GWs

# %%
gwSpk005, nBinsk005, nSpectrak005 = load_spectrum(dirk005 + "spectra_gws.txt")
gwSpk02, nBinsk02, nSpectrak02 = load_spectrum(dirk02 + "spectra_gws.txt")
gwSpk08, nBinsk08, nSpectrak08 = load_spectrum(dirk08 + "spectra_gws.txt")

plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plot_spectrum(gwSpk005, 1,  nBinsk005, nSpectrak005)
plt.ylabel('$\\tilde\Omega_{GW}$');
plt.title(r'$kIR = 0.05$')
plt.axvline(k_max, color='k', linestyle='--')
plt.axvspan(k_delta[-1], k_delta[0], color='green', alpha=0.3)

plt.subplot(1, 3, 2)
plot_spectrum(gwSpk02, 1,  nBinsk02, nSpectrak02)
plt.ylabel('$\\tilde\Omega_{GW}$');
plt.title(r'$k = 0.2$')
plt.axvline(k_max, color='k', linestyle='--')
plt.axvspan(k_delta[-1], k_delta[0], color='green', alpha=0.3)

plt.subplot(1, 3, 3)
plot_spectrum(gwSpk08, 1,  nBinsk08, nSpectrak08)
plt.ylabel('$\\tilde\Omega_{GW}$');
plt.title(r'$kIR = 0.8$')
plt.axvline(k_max, color='k', linestyle='--')
plt.axvspan(k_delta[-1], k_delta[0], color='green', alpha=0.3)

plt.tight_layout()
plt.show()
